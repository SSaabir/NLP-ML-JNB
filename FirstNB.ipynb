# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np

data = np.array([
    (101, 'Laptop', 'Electronics', 1200, 150, 4.5),
    (102, 'Smartphone', 'Electronics', 800, 300, 4.7),
    (103, 'Tablet', 'Electronics', 300, 200, 4.3),
    (104, 'Headphones', 'Accessories', 150, 400, 4.0),
    (105, 'Smartwatch', 'Electronics', 200, 250, 4.2)
], dtype=[('ProductID', 'i4'), ('ProductName', 'U20'), ('Category', 'U20'),
          ('Price', 'i4'), ('UnitsSold', 'i4'), ('Rating', 'f4')])


print(data)
# Out:
# [(101, 'Laptop', 'Electronics', 1200, 150, 4.5)
#  (102, 'Smartphone', 'Electronics',  800, 300, 4.7)
#  (103, 'Tablet', 'Electronics',  300, 200, 4.3)
#  (104, 'Headphones', 'Accessories',  150, 400, 4. )
#  (105, 'Smartwatch', 'Electronics',  200, 250, 4.2)]

# %%
import matplotlib.pyplot as plt

#plt.scatter(data['Price'], data['UnitsSold'], c=data['Rating'], cmap='viridis', s=100)
#plt.colorbar(label='Rating')

plt.pie(data['UnitsSold'], labels=data['ProductName'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d985b03390>,
# ...
#  [Text(1.0285178674903697, 0.390065374332384, 'Laptop'),
#   Text(0.13259035428756452, 1.0919797607785129, 'Smartphone'),
#   Text(-0.9740016941590571, 0.5111953636089501, 'Tablet'),
#   Text(-0.6248710016910446, -0.9052824041400731, 'Headphones'),
#   Text(0.9052822079827241, -0.6248712858740784, 'Smartwatch')],
#  [Text(0.5610097459038379, 0.2127629314540276, '11.5%'),
#   Text(0.07232201142958064, 0.595625324061007, '23.1%'),
#   Text(-0.5312736513594857, 0.278833834695791, '15.4%'),
#   Text(-0.34083872819511524, -0.49379040225822163, '30.8%'),
#   Text(0.493790295263304, -0.3408388832040427, '19.2%')])
